# %% [markdown]
# <a href="https://colab.research.google.com/github/pratikshapatil28518-a11y/Patil-pratiksha-/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=(input("length of string"))
print(a)

a=input("enter first string")
b=input("enter second string")
c= a+b
print(c)

a="pratiksha"
b="patil"
c=a+b
print(c)
# Out:
# length of string25
# 25
# enter first string20
# enter second string30
# 2030
# pratikshapatil
